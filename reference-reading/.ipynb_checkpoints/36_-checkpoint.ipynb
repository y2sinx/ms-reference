# %% [markdown]
# 含氢分子 在过渡金属表面上 吸附能的缩放特征

# %% [markdown]
# 密度泛函理论计算用于 CH x ,  x 0 ; 1 ; 2 ; 3, NH x ,  x 0 ; 1 ; 2, OH x ,  x 0 ; 1, SH x ,  x 0 ; 1 吸附在一系列密集和阶梯式过渡金属表面上.  我们 发现所考虑的任何分子的吸附能量大致与 中心, C, N, O或S原子的吸附能量, 缩放常数仅取决于 x .  一个模型 建议理解这种行为.  缩放模型被开发成一个通用框架 估算加氢和脱氢反应的反应能量. 在分子和金属之间形成键 表面是一些重要的现象 包括多相催化在内的[ 1] ], 联系 - 分子电子学中的[ 2 ], 和锚定 用于传感器和其他生物医学的生物分子到固体 申请[ 3 ].  吸附能量是关键数量 描述分子相互作用的强度 表面.  吸附能量可以通过测量 先进的表面科学技术[ 4 - 6 ].  或者,  密度泛函理论(DFT)提供了可能性 以合理的精度计算吸附能 [ 7 - 11 ].  虽然实验和DFT计算都是 对于有限数量的系统来说, 它们很难实现 详细介绍所有可能有趣的广告 - 吸附系统.  因此需要简单 具有估计第一个债券能量的能力的模型 筛选有趣的系统.  一个成功的模型将 也暴露了决定力量的重要因素 吸附物 - 表面键的结合.  在本函中, 我们将 开发这种含氢分子的模型.  我们使用DFT计算来推导出许多相关性 在吸附能量之间, 我们然后提出一个模型 解释他们.  该模型显示了吸附物的含量 效价, 以及 d电子的性质 表面, 决定吸附能量.  我们进一步 将缩放模型发展成估算方法 氢化或脱氢反应能 过渡金属表面的有机分子.  该模型 测试反应的完全DFT计算 碳氢化合物, 醇类, 硫醇和氨基酸.  首先, 我们提出了广泛的DFT计算结果 CH x ,  x 0 的吸附能 ; 1 ; 2 ; 3, NH x ,  x 0 ; 1 ; 2, OH x ,  x 0 ; 1, SH x ,  x 0 ; 1的范围 密集和阶梯状的金属表面.  该研究 - 密集的fcc(111), fcc(100), hcp(0001)和 bcc(110)曲面, 阶梯fcc(211)和bcc(210) 表面.  每个表面由(2 2)或a建模 (1 2)表面单元电池用于密堆积和阶梯式 表面, 分别.  每块板的厚度为3 在垂直于紧密堆积的方向上的层 表面.  这些厚度足以捕捉趋势 在化学吸附能量学中.  吸附物和 允许最顶层在所有配置中完全放松 在Fe, Ni和Co的情况下, 自旋极化是 考虑到了.  不同的结合能 物种已被用于最稳定的吸附位点 在所有表面上.  RPBE功能[ 12 ]在一般情况下 - 梯度近似用于描述交换 和相关效应.  计算方法和设置 参考文献中描述了 [ 13 ].  图 1总结了DFT计算的结果.  我们发现所研究的所有分子都具有吸附作用 分子 A H x的 能量与分子线性相关 原子 A的 吸附能 ： E A H x E A ‡ ： (1) 线性关系周围有一些分散, 但我们 请注意, 虽然吸附能量有几​​个不同 电子电压超过这里考虑的金属范围,  平均绝对误差(MAE)仅为0.13 eV.  一些 这种分散与吸附位点的差异有关 吸附不同量的氢.  CH 3 , for 例如, 通常喜欢在其上的一个吸附位点 密集的表面, 而C喜欢三重的网站.  如果 我们在单倍使用C的吸附能量 吸附部位作为参考, 相关的质量 - 重刑变得显著更好(MAE 0：06电子伏特); 看到 图 2 .  我们还发现当我们使用引用时 与目标分子相同的配置, 缩放 行为包括具有与之相同精度的合金 元素金属(图 2 ).  主要观察图.  1和2是斜率 线性关系 在Eq.  ( 1 )给予好处 通过 A H x中 的H原子数近似为 ...... x † ... X 最大 Y X†= X max时 , 其中x max是H的最大数目 原子可以键合到中心原子 A ( x max 4为 PRL 99, 016105(2007) 物理评论信 一周结束 2007年7月6日 0031-9007 = 07 = 99(1) = 016105(4) 016105-1 ©2007美国物理学会
# 第2页
# A C, X 最多 3为A N, 并且x 最多 2对于A O; S).  由于... X 最大 Y X†是一个高x分子的化合价, 我们 得出结论, 对于所考虑的四个分子家族 斜率仅取决于吸附物的化合价.  在 以下我们将考虑允许我们使用的模型 了解这种效果的起源.  对于一些被考虑的系统, 简单的效价或 债券计算论点[ 14 ]可以解释结果： 比较紧密包装的CH, CH 2和CH 3 面孔, 我们通常会发现CH(效价为3) 三重吸附位点, CH 2 (效价2)更喜欢 双重吸附, CH 3 (1的效价)优先选择 - 折叠吸附.  这些趋势的含义是 碳原子上的不饱和键形成键合 表面金属原子; 实际上, 每个不饱和 sp 3杂化 在中心C原子上独立地与 d状态结合 最近邻金属原子, 符合 图 1中的 斜坡 .  但是, 这张图片不能包含 吸附原子C.吸附的C也吸附三倍 站点(忽略远程重建), 但事实并非如此 有四个债券可以解释所有的C 数据如图 1所示 .  我们还注意到整体扩展行为 ior与吸附几何形状无关, 因此也是如此 粘接的细节; 见图 2 .  图中的缩放比例 1 因此,  2必须有一个更一般的解释 包括CH, CH 2和CH 3的 上述参数 特殊情况.  我们将基于 d- band模型进行分析 已成功用于了解趋势 从一种过渡金属到下一种金属的吸附能量 [ 8 ,  15 - 19 ].  根据d- band模型, 它是有用的 想到吸附质 - 表面键的形成 分两步进行.  首先, 我们让吸附物状态 与过渡金属 sp状态相互作用 , 然后我们 包括耦合到 d 的额外贡献 状态： ËÉ‡SPèd： (2) 与金属 sp状态的耦合通常有助于 粘合的最大部分, 涉及相当多的 桥接和电荷转移.  在变化方面 然而, 一个过渡金属到下一个金属可以考虑 - 本质上是一个常数; SP 的带广阔,  并且所有过渡金属每个金属都有一个 sp电子 原子处于金属状态[ 20 ].  根据d- band 模型, 对债券变化 的主要贡献 从一种过渡金属到下一种金属的能量来自 与金属 d状态的耦合 ; d国形成狭隘 接近费米能级的状态带, 宽度和 d带的能量在转变之间变化很大 金属.  根据 d- band模型, 所有变化 因此,  在图 1中 观察到的金属应该是 由 E d 给出 .  这意味着x的依赖性 E A H x ... x †必须由d耦合单独给出：让我们 暂时假设 A H x 的 d耦合是 与化合价参数成比例 定义如上： Ë 一个 H x d ...... x † E A. d (3) 使用Eq.  ( 1 ), 这将导致那种关系 图 1 .  我们可以写出分子的吸附能 在分子A的吸附能作为换算的高x -6 -5 -4 -3 -2 ΔE C (eV)的 -2.25 -2 -1.75 -1.5 -1.25 -1 -0.75 -0.5 Δ Ë CH 3 (eV)的 适合度：y = 0.24x-0.02 适合度：y = 0.28x-0.27 铱 铂 钯 你 铑 茹 铜 金 银 铱 茹 铑 铂 钯 你 铜 金 银 铜 3 铂 钯 3 金 铜 3 铂 钯 3 金 在吸附部位上 最稳定的吸附部位 图.  2(颜色).  CH 3的 结合能量相对于 C的结合能在最稳定的位点吸附 (三角形)和CH 3和C都已固定的情况 在顶部网站(广场).  图.  1(颜色).  CH x中间体的吸附能 (十字： x 1;圆： x 2;三角形： x 3), NH x inter- 介导(圆圈： x 1;三角形： x 2), OH和SH inter- 根据C, N, O和S的吸附能绘制中间体,  分别.  分子 A 的吸附能定义为 A 的总能量吸附在最低能量位置 在表面之外减去 A in 总能量的总和 真空和干净的表面.  数据点代表结果 适用于各种密封(黑色)和阶梯(红色)表面 过渡金属表面.  此外, 还有金属数据点 OH x 包含fcc(100)结构(蓝色) .  PRL 99, 016105(2007) 物理评论信 一周结束 2007年7月6日 016105-2
# 第3页
# E中的 高 xë 一个 H x d ‡ E 一个 H x SP ...... x † E A. d ‡ E 一个 H x SP ...... x † E A ‡ ; (4) 哪里 Ë 一个 H x SP ÿ ...... x † E A. sp 独立于金属 有问题.  参数 每个都可以从图1中读出 A H x = A组合; 见Eq.  ( 1 ).  参数 可 从任何过渡金属的计算中获得.  在里面 以下所有模型数据均使用 Pt(111)作为参考系.  基本问题仍然是, 为什么耦合到 d 国家应该按照吸附物的价数进行扩展 式.  ( 1 ).  我们无法提供一般的严谨证明 缩放, Eq.  ( 1 ), 很可能没有这样的证据 - 图 1中的 散点表示线性关系是唯一的 近似.  然而, 我们要做的是表明 式.  ( 1 )应该大致保留这种系统 在图 1中进行了研究 .  吸附物态与 d带的耦合具有 两个贡献[ 15 ,  16 ,  21 ], EË HYB d ‡ E orth d .  该 第一个术语描述了与之相关的能量变化 形成键合和反键合状态.  自从 d 耦合通常可以用二阶扰动来描述 - 理论[ 8 ,  15 ,  21 ], 我们可以写E HYB d / E orth d / V 2 广告 ,  其中 V ad是哈密顿量之间的矩阵元素 吸附物和金属 d状态[ 21 ].  如果有更多 一个吸附态, 总相互作用能量将扩大 来自吸附态的贡献总和,  V 2 ad P i V 2 我 .  我们建议 V 2 广告 / 对于那种 在图 1中 考虑的系统 , 这直接给出了 方程的关系 ( 1 ).  原因在下面给出.  耦合强度 V 2 广告 ... F R AÿI G†是的函数 金属邻居的数量和他们的距离 吸附物.  由于 d耦合通常是次要的 - 对于键能而言, 它是 sp耦合 主要决定吸附的键长, R Aÿ 我 .  当H原子加到中心C, N, O或S原子上时,  吸附键长度增加和耦合 力量减少.  有效介质理论(EMT) [ 22 ]提供了一种量化这种效果的简单方法.  在里面 EMT原子 A与其他原子的键合 附近近似于 A与a 的相互作用 a的均相电子气(有效介质) 由密度的球面平均值 n给出的密度 由周围的原子提供 ：电子é 坎 ... N†.  这种相互作用的局部密度近似 能量很好地描述了债券的一般趋势 - 包括金属中原子的键长, 吸附物 在金属表面和分子[ 22 - 24 ].  能量 将原子嵌入均相电子气中,  E hom ... n †, 通常具有特定电子的最小值 tron密度,  n 0 , 原子A的平衡几何是 由 A经历最佳的位置给出 电子密度 , N N 0.  考虑例如金属表面外的C原子.  吸附键长度由外部距离给出 表面电子密度的表面 周围的C原子是 正 冲浪 N 0.  现在将H原子添加到C中 原子.  每个H原子将为C提供电子密度 原子和表面所需的电子密度 达到 N N 0越小.  对于固定吸附部位(一个,  表面之间的键长. 二或三倍) 因此原子和C原子必须增加.  Alterna- 吸附位点可以像CH一样改变,  上面讨论的CH 2和CH 3 .  在那种情况下, 我们会 期望C-金属键长度与 x 无关 ,  由于金属配位数的变化相关 完全符合H配位数的增加 这个系统的序列.  这正是我们的意思 在计算中找到.  回到一般情况下,  从获得所需的面 N 冲浪 电子密度 N N 0将继续下降为H的数x 原子增加.  当 x 4时, H原子必须有贡献 中心C原子所需的所有电子密度,  4 N H n 中 0中, 由于甲烷分子不结合于 表面(忽略范德瓦尔斯相互作用).  该 平衡时表面的密度贡献 因此, CH x的 站点 n 冲浪 ... X 最大 Y X† x 最大 n 0 ...... x † n 0 ： (5) 等式中x 的线性依赖性 .  ( 五 )是基于 合理假设对电子的贡献 所有 x H原子的密度都是相同的 , 即总和 密度应该加起来为 n 0 [ 25 ].  电子密度n 可视为广义债券订单[ 26 ,  27 ], 和 的要求, 即 N N 0是然后键顺序的一个例子 保护.  因为我们使用EMT来模拟 sp贡献 键合,  n surf表示外部的sp电子密度 表面.  表面外n 冲浪 的衰减长度是 通过工作函数(能量)渐近地给出 相对于真空的费米水平).  由于 d州有 能量接近费米水平, 它们的衰变长度 大致相同.  这意味着第一次近似 - 重刑 V 2 广告 与 n冲浪鳞片 .  因此我们证明了这一点 以下关系约占,  E d ... x †/ V 2 ad ... x †/ n surf ... x †/ X 最大 Y X x 最大 ...... x † ; (6) 这意味着Eq.  ( 1 ).  鉴于上面提供的理解, 我们可以尝试 概括了图 1中 的发现 .  对于任何氢化或 分子键合的脱氢反应 过渡金属表面通过C, N, O或S原子, 我们应该 能够估计所有过渡的反应能量 金属只给出一种金属的反应能量.  对于 每个原子 A i i 1 ; ... ; N粘合到表面, 我们 确定期间价格参数的变化 i 反应, 然后我们可以估计债券的变化 从债券的变化中获得完整系统的能量 A i的 能量 ： PRL 99, 016105(2007) 物理评论信 一周结束 2007年7月6日 016105-3
# 第4页
# E. X N. 我 1 ... I E A I‡ 我 † X N. 我 1 ... i E A i †‡ ： (7) 改变了 特定反应的参数 需要通过计算得到一次性计算 单一金属的反应能量.  在图 3中 , 我们进行比较 该模型完成氢化的DFT计算 或脱氢一系列碳氢化合物, 醇类,  硫醇和氨基酸.  在每种情况下, 我们都计算了 来自Pt(111)数据.  模型之间的协议 并且完整的DFT计算表明该模型具有 描述绝对量值和. 的力量 氢化或脱氢反应能的趋势 许多有机分子的生成反应 过渡金属表面.  我们注意到缩放关系 可以很容易地推广出来的吸附能量 任何氢化物质 A H y用作参考 而不是 A. 通过将现有模型与布朗斯台德 - Evans-Polanyi型相关已建立 激活障碍和反应能量之间 用于表面反应[ 8 ,  10 ,  11 ], 有可能估计 - 配对表面催化剂的全部势能图 - 基于C, 任何过渡金属的裂解反应,  N, O和S化学吸附能量和a的计算 单金属.  我们建议这将是一个有用的工具 筛选新催化剂.  这样的估计可以 随后进行完整的DFT计算和前 最有趣的系统的periments.  原子级材料设计中心是赞助 由伦德贝克基金会主持.  额外的支持 来自丹麦研究理事会和丹麦人 科学计算中心也得到了认可.
