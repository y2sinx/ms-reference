# %% [markdown]
# 跳到主要内容跳到部分
# SpringerLink数据库
# 搜索
# 菜单
# 家
# 登录
# 材料建模手册 第1-24页| 引用为
#
# 机器学习与计算化学中的大数据
# 作者
# 作者和附属机构
# RafaelGómez-Bombarelli电邮作者AlánAspuru-Guzik
# 1.
# 2.
# 3.
# 生活参考工作条目
# 首先在线： 2018年7月10日
# 抽象
# 实验化学和计算化学的年轻学科一直渴望增加数据量，速度和多样性。最近在机器学习，数据库和自动化方面的软件开发以及快速协处理器，网络和存储方面的硬件进步推动了自动化和数字化。计算化学似乎处于大数据革命的边缘。
#
# 在本章中，我们将讨论这些数据驱动范例中有多少是长期趋势的一部分，数据长期以来一直是许多化学问题的核心。现代化学研究人员可以挖掘高价值策划培训数据的化学数据的历史资料库进行了审查。描述了可用于高数据计算化学的现代自动化工具和数据集。讨论了计算机驱动的分子材料在光电子学（光伏和发光二极管）和电能存储中的应用的当前应用。最后，分析了机器学习方法对结构 - 性质关系和化学空间的计算化学领域的影响，重点是生成模型。
#
# 下载 参考工作条目PDF
# 1简介
# 几十年来，化学一直是一个大数据企业。在该术语推广之前很久，化学家们一直在努力使用化学数据集，其数量，种类和速度超过了他们可用工具的能力。首先，化学家们一直在努力解决化学空间的巨大问题。自计算机问世以来，化学家一直是数字技术的创造者和早期采用者，用于化学数据的存储，处理和检索。同样，互联网的出现引发了加速化学科学知识创造和共享的新时代。
#
# 在诸如消费者分析，广告，运输，医疗保健或金融等领域，大数据和机器学习方法的最明显收益来自于尽可能多的有利特征的子区域：数据生成成本低廉，数字化起源或容易数字化，高度组织化，一致化，极其丰富。虽然丰富的化学数据往往是昂贵的，生成，异构，手工制作和稀疏。化学数据输入和管理通常是手动完成的; 由于异构的来源和报告标准以及化学报告的技术复杂性，这些任务需要大量的专业知识。近年来，随着诸如显微镜或光谱仪的化学仪器产生数字化数据，可以由单个装置生成非常大的数据集。本地大数据，但在尝试合并来自不同组或设备的结果时仍然面临类似的障碍。
#
# 计算化学方法具有一系列特征，使得它们非常适合这种数据驱动的范例，并且被证明是实现化学中大数据愿景的完美测试基础。计算化学软件的输出从头到尾进行数字化。即使它依赖于自定义格式的输入和输出文件，自动创建和处理这些文件也是一项简单的任务。当使用相同的计算机代码时，计算结果可以复制到浮点精度，并且即使在不同的程序中也是如此，只要它们使用相同的基础算法。因为计算本质上是一种商品，所以结果可以通过成本线性缩放生成任意数量 - 或者甚至是次线性的，这要归功于机器学习方法。最后，
#
# 在本章中，我们将分析计算化学如何包含大数据以加速发现急需的新分子，以及这些新生成的数据集如何允许应用和开发机器学习技术，使其更加强大。
#
# 2化学数据库
# 化学中大数据方法的最初发展历来侧重于巩固，策划和索引文献和经验数据。解决这些任务是计算机在化学中的首批应用之一，并且仍然是开发新的化学计算工具的关键驱动因素。
#
# 化学文摘社（CAS）创建于1907年，用于保存化学文献和报告物质的完整记录，遵循欧洲先前的摘要期刊的理念，如Chemisches Zentralblatt和19世纪的编辑，如Beilsteins Handbuch der organischen Chemie，Gmelins Handbuch der anorganischen Chemie，或默克索引。它在第一年包含超过12,000个索引，在1937年创下了百万分之一的记录.CAS历史上依靠成千上万的志愿者为每篇论文创建摘要和索引信息 - 而不是今天在亚马逊的机械土耳其人那么远 - 并逐渐将它们分开六十年代末和九十年代。此外，到20世纪50年代，CAS雇用了数百名员工，强调了大数据对化学的巨大价值以及将相同数据整齐地划分为可用形式的巨大成本。
#
# 20世纪60年代后期，化学应用数字计算机的应用通过促进化学数据库的存储，进入和非常重要的查询，开始了化学大数据的数字化。基于CAS计算机的化学品登记系统，就像之前的Beilstein登记号码一样，为化学品分配独特的个人任意数字。它于1964年在内部首次亮相，并逐步更新和扩展，为越来越现代的查询和检索工具奠定了基础，使用命令行和图形界面从本地或在线记录中检索数据。在七十年代中期，记录显示每年约有三百万条记录并且每年增加数十万条，登记册在2007年呈指数增长，达到第3000万种化学物质，2009年增长了5000万，2015年增长了1亿。
#
# 1965年，剑桥大学的Kennard小组开始收集已发表的小分子晶体学数据。这项工作已发展成为所谓的剑桥结构数据库，该数据库现在拥有近100万个来自X射线和中子衍射分析的精选项目（Groom等人，2016年）。同样在20世纪60年代后期，布鲁克海文国家实验室和得克萨斯A＆M大学的共同努力启动了蛋白质数据库，这是一个大型生物分子（如蛋白质和核酸）的三维结构数据库，现在拥有超过120,000个条目（Berman等人2000 ; Bernstein等人1978 ; Meyer 1997）。
#
# 实验晶信息的其他储存库（布鲁诺等人2017年）是晶体开放式数据库（COD）（Gražulis等人2009，2012），其存储用户提交的数据; 无机晶体结构数据库，由FIZ Karlsruhe和NIST合作生产，用于存储无机固体的晶体结构（Belsky等，2002）; 和存储粉末衍射图谱的国际衍射数据中心（ICDD）（Faber等，2002）。
#
# 互联网的兴起引发了其他大数据存储库的推出，以及现有化学和材料在线可用性的扩展。研究数据库登记处汇总了包括化学和材料科学在内的许多科学学科的多个储存库和数据集的列表（Pampel等，2013）。
#
# 美国国家标准与技术研究所自1996年以来一直主持NIST化学WebBook（Linstrom和Mallard 2001），这是一本主要是光谱和热力学数据的汇编，最初是在手册和表格中编写的。此外，近200个标准参考数据集包括化学家感兴趣的其他数据。NIST 101（III 1999）特别包含约1800个气相原子和小分子的计算数据量子化学数据和用于比较实验和计算理想气体热化学性质的工具。
#
# 由于专利和专利申请是开放的，它们是一个大数据，信息丰富的资产。然而，专利文献倾向于仅基于文本或基于图像，并且将它们数字化为可用于数据驱动方法的格式是一个长期挑战。欧洲，美国，日本专利局和世界知识产权组织可以在线访问和查询，但没有系统地注释。美国专利商标局通过其复杂的工作单位计划，在专利申请中提供了分子的数字表示，从而简化了数据处理管道。
#
# 在开放数据领域，NextMoveSoftware发布了近百万种化学反应，通过自动文本挖掘提取专利中报告的相关实验部分，涵盖1976年至2013年期间.SCRIPDB包含策划合成，化学品和反应来自从CWU文件收集的专利文献来自授予的美国专利（Heifets和Jurisica 2012）。
#
# SureChem是另一个分子数据库，于2012年开放给SureChemBL。它由IBM的战略IP洞察平台使用，最初从大约470万个专利（1976-2000，仅文本）中提取了200多万个化学结构，随后扩展到包括截至2010年底发布的专利，并且化学结构还得到了来自美国CWU和图像（2001-2010）（Papadatos等，2016）。UniChem试图统一并交叉引用这些多个数据库（Chambers等，2013）。
#
# ChemSpider是一个化学品数据库，拥有来自480多个数据源的6000多万个条目。它最初是一家私营企业，于2009年被皇家化学学会（RSC）收购。它包括一个众包组件，但只有有限的下载量（Pence和Williams 2010）。
#
# 由于具有生物活性的可能的小有机分子的大尺寸，生物靶标的大量和多样性，许多生物测定和测量的高维度以及医疗应用，化学信息学，生物化学和药物的高价值发现应用程序是化学中大数据应用的关键目标。药物和化学品的毒理学信息也是有趣的生物相互作用，记录在几个公开的数据库中。
#
# 国家生物技术信息中心（NCBI）是美国国立卫生研究院（NIH）的美国国家医学图书馆（NLM）的一部分，它拥有生物技术领域的多个数据集和信息学工具。对化学特别感兴趣的是PubChem，这是一个分子数据库及其针对生物分析的活动。该项目于2004年启动，现已汇集了540多种来源，超过9亿种化合物，其中近250万种具有2.33亿种生物活性结果。作为联邦政府资助的服务，PubChem被认为与CAS（Kaiser 2005）等营利性存储库发生冲突。
#
# ChemBL是一个开放式数据库，包含针对药物样生物活性化合物的结合，功能和ADMET（吸收，分布，代谢，排泄）测量，对超过100万种化合物和11,500种蛋白质靶标进行了近1500万次生物活性测量（Gaulton等）人2012）。DrugBank是一种网络可访问的化学信息学数据库和服务，结合了药物分子的结构和生物学目标数据。该数据库包含超过9000种小分子药物，3000 FDA批准的药物，以及数据近17000药物靶协会（威沙特等人。2006年，2018）。化学实体生物学兴趣数据库也遵循类似的重点（Degtyarenko等人，2008）。
#
# PDBbind数据库匹配来自文献的已发表的亲和常数，其配体 - 蛋白质系统的3D结构存储在PDB中，经历定期更新（Liu等人，2015 ; Wang等人，2004）。BindingDB（Chen等人2001 ; Gilson等人2016）和AffinDB（Block等人2006）也旨在完成类似的任务。比较毒物基因组学数据库是一个基于志愿者的基因组资源，致力于毒理学相关基因和蛋白质及其与化学物质和毒素的相互作用（Davis等人2017 ; Mattingly等人2003年））。MACiE含有酶反应机制，侧重于酶催化机制的进化和化学机理的分类（Holliday等，2005）。
#
# 这些服务是化学领域的大数据先驱，突出了早期对化学如何成为高维，稀疏数据领域的理解，大数据方法可以创造巨大价值，以及收集和管理化学数据的高成本。对于机器学习应用程序，这些存储库提供极其有价值的标记数据。
#
# 3大计算化学
# 计算化学领域很快就跟随了第一台数字计算机的部署，并且发展迅速，与算法和硬件的发展相匹配，并且也有自己的贡献。通常情况下，执行的化学计算将推动可用的硬件运行：使用大量内存或存储在超级计算机中的多个核心上并行运行。
#
# 从这个意义上说，从它们产生的输出数据的数量和速度来判断，以及硬件要求的压力，计算化学计算一直是大数据，基本上与可用资源允许的一样大，并且是大的驱动因素 - 数据技术。
#
# 在本章中，我们将重点关注计算化学的应用，这些计算化学结合了体积和速度，并且由于具有很大的粒度，因此也具有很高的多样性。这些是（i）分布式计算的情况，其中小的计算有效载荷被分配到大型小型计算机网格，并且在计算之后，结果被合并和处理，以及（ii）高吞吐量虚拟筛选，其中数千个候选分子或材料以自动化方式单独计算，并进行数据驱动的最高性能候选材料搜索。
#
# 3.1计算化学中的自动化和数据库
# 已经开发了许多工具来自动化计算化学数据的创建，提交，转移，处理，解析，存储和查询。最基本的网络示例之一是Basis Set Exchange，最初在环境分子科学实验室组装，其中大多数元素周期表的无数精选基础集可以多种格式下载（Feller 1996 ; Schuchardt et人。2007）。
#
# 存在近六个平台，其具有类似的理念，以实现以下部分或全部：材料科学自动化和固态电子结构计算; 数据处理和这些计算的分析; 以及用于虚拟发现和机器学习目的的这些计算输出的集中式，Web可访问的存储库。多种解决方案提供了一些重叠的功能，通常在材料领域，并且最近已经过审查（Lin 2015）。
#
# 电子结构项目（Klintenberg等，2002 ; Ortiz等，2009）利用ICSD的结构数据来筛选新型无机材料。
#
# 所述计算材料库（兰迪斯等人。2012）提出了一种用于计算机驱动的材料设计集成软件解决方案。它是量子材料信息学项目生态系统的一部分，该项目还包括原子模拟环境，这是一个用于原子模拟的python库（Hjorth Larsen等人2017）。
#
# AFLOW是高通量材料发现的自动框架（Calderon等人2015 ; Curtarolo等人2012a），匹配库Aflowlib.org主持并向公众提供这些计算结果（Curtarolo等人2012b） 。它现在包含1,748,704种物质化合物 - 计算出的物质超过173,121,696。
#
# Python的材料基因组学（pymatgen）是用于固态DFT计算的分析材料（Ong等。一个开源Python库2013），其还具有匹配材料中的应用程序编程接口（Ong等。2015年）进行交互材料项目是一个大型材料计算数据库（Jain等，2013）。该生态系统中的其他计算工具包括用于错误处理的Custodian，用于工作流管理的Fireworks等工具。材料项目工具和数据已在100多篇已发表的论文中使用，近200篇由其创作者使用。
#
# 开放式量子材料数据库（OQMD）是一个完全开放的项目，可以对来自ICSD的化合物以及假设化合物进行400,000多次DFT能量计算，可能发现有效但尚未合成的化学物质（Kirklin等人，2015）。
#
# AiiDA（Pizzi等人，2016）是一个灵活且可扩展的信息学基础设施，用于模拟，数据和工作流程，重点关注材料的平面波DFT计算和对数据来源​​的重视（Merkys等人2017）。
#
# 新材料发现存储库的建立是为了以与管道无关的方式托管，组织和共享材料数据（Goldsmith 2016），并通过各种计算机代码托管超过4400万开放访问用户提交的总能量计算。
#
# ioChem-BD平台提供了类似的解决方案，重点是分子数据（Álvarez-Moreno等人，2015）。几个工具包解决了缺陷的模拟和作用，例如MAST（Mayeshiba等人2017），PyDII（Ding等人2015）和其他（Goyal等人2017）。PyChemia是一个用于自动化原子模拟的python库，侧重于一些DFT代码和数据挖掘功能的材料和接口。
#
# 计算化学结果的倍数数据集纯粹旨在产生不同的训练数据。QM9含有B3LYP / 6-31 G（2df，p）结果，用于由CHONF组成的134k稳定小有机分子，包括谐波频率（Ramakrishnan等，2014）。PubChemQC最近尝试为机器学习方法创建训练数据，该方法基于B3LYP / 6-31G *水平的密度泛函理论（DFT）和超过2个的10个最低激发态计算了300万个分子的基态电子结构在TD-DFT / B3LYP / 6-31 + G *理论水平上的百万分子（Nakata和Shimazaki 2017）。ANI-1包含2000万个构象的能量和DFT水平特性，超过50,000个沿正常模式扭曲的小有机分子（Smith等。2017）。也可获得从头算分子动力学：在理论的PBE水平上，500 K时的5,000帧，对于C 7 O 2 H 10的 113种结构异构体和8种小有机分子的数十万帧（Chmiela等人 2017 ;Schütt等人。 2017年）。
#
# 大量用于数据处理的内部工具已发展成可用于计算输出的数据分析的开放库：基于python的cclib，用于解析和解释计算化学包的结果（O'boyle等人，2008）; ESTEST，量子化学计算产出的比较，验证和共享的自由框架（Yuan和Gygi 2010）; ORBKIT，也是基于python的库，用于对来自多个代码的量子化学波函数输出进行后处理; （Hermann等人，2016年）; 和PyGlobal，对于DFT计算面向电子表格的输出后处理工具（Nath等。2016）。其他工具也可用于输入生成和流水线计算，例如JACOB（Waller等人2013）用于企业应用的计算化学框架，PyADF用于使用ADF包编写多尺度量子化学（Jacob等人2011）。
#
# 这种充足的景观表明，增加量子化学计算的速度和体积是非常有趣的。然而，这些增加伴随着各种应用的折衷。由于增加的复杂性，其中大多数很少被视为在创建它们的团体或财团之外采用（Thygesen和Jacobsen 2016）。
#
# 3.2高吞吐量虚拟筛选
# 随着计算方法变得更加准确并且计算硬件更加经济实惠，在合成之前自动预筛选化合物的可能性变得更有希望。各个团队已经使用HTVS发现了许多无机材料。这些在本书的其他章节中进行了深入的处理。在这里，重点将放在有机光电子领域的有机分子材料上，用于光能互换（光伏和发光二极管）和电能储存（Pyzer-Knapp等，2015）。
#
# 3.2.1光电子学
# 清除能源项目（CEP）包括志愿者，分配计算工作和HTVS愿景的概念。自2006年左右开始以及整个两个阶段开始，该项目在IBM World Community Grid上运行，志愿者将计算机时间捐赠给虚拟屏幕p型和后来的n型有机光伏低聚物。
#
# CEP解决了化学化合物自动化虚拟测试的许多挑战：候选分子的程序化生成，量子化学计算的自动化，数据存储和分析。
#
# 通过活性位点的共价连接组合20个片段的池，并且还通过形成与这些标记的反应性原子相邻的稠合环，处理的CEP分子产生上升至四聚体并产生超过200万个候选物，其被彻底筛选。进行的量子化学计算包括多个DFT功能，相当于迄今为止最大的计算化学项目。使用Scharber模型评估候选四聚体的光伏效率，假设富勒烯作为电子受体以及原始和经验校准的供体能量水平。大数据集的统计分析产生，得到了最高和最低有前途的片段和片段的组合的相关性（Hachmann等人2011，2014; Olivares-Amaya等。2011）。
#
# 由于理论数据集较大，并且OPV领域存在大量独立实验结果，CEP已经证明是材料发现新方法的试验场。使用来自文献的一组实验结果（Lopez等人2016）改进理论气相结果和捕获体积效应的基于概率核的校准方案改善了DFT计算的预测性能（Pyzer-Knapp等人。2016）。
#
# 后来的子项目专注于从100多种常见有机部分的组合中虚拟筛选超过50,000个非富勒烯电子受体。对选出的先导化合物也进行了时间密度泛函理论计算。二酮吡咯并吡咯和醌型噻吩衍生物显示出良好的前景，并被提议进行额外的研究（Lopez等人，2017）。
#
# 在较不庞大的规模上，其他工作也涉及对体相异质结太阳能电池组件的筛选，例如超过780种不同共聚物供体材料的组合带隙设计策略（Shin等人，2014）。
#
# 一些研究已经解决了其他类太阳能电池的分子虚拟发现，例如基于TiO 2的染料敏化太阳能电池，优于普通染料（Martsinovich和Troisi 2011）以及卟啉（Ørnsø等人，2014）。
#
# 在热激活延迟荧光（TADF）有机发光二极管领域，已经报道了将计算化学与应用材料发现的深度学习相结合的成功范例（Gómez-Bombarelli等人，2016））。使用模拟现有凝视材料上的交叉偶联反应的定制软件，从200多个起始供体和受体片段中创建了跨越近200万个可行化合物的数据库。使用精确的，经验校准的TD-DFT计算估算化合物的TADF特征及其颜色。为了加速结果，通过神经网络筛选候选者，使用拓扑指纹作为特征。具有最有希望的预测化学性质的主要化合物由专家团队评估，他们合成并测试了共识冠军化合物。然后在光电器件中测试这些器件，它们与人类生成的冠军化合物的性能相匹配（图1）。
# 在新窗口中打开图像图。1
# 图。1
# TADF OLED化学空间概述。红点表示与文献中先前的实验报告重叠，橙色三角形对应于理论导联，青色正方形表示实验证实的理论导联。分子候选物的对数密度作为单线态 - 三线态间隙和振荡器强度的函数示出。虚线遵循估计的延迟荧光速率的等值线
#
# 3.2.2电解质和储能
# 能源存储是材料科学和工程领域最活跃的领域之一，因为对轻型，高能量密度应用（如移动电话或运输和静态，低成本，网格级存储）的需求强劲。
#
# 液流电池是大型静电电池，其中液体电解质储存在罐中并在充电或放电时在电化学电池中循环。尽管与诸如锂离子的固态电池相比它们显示出稍差的能量密度，但是由于较低的成本和使用地球丰富且廉价的电解质材料，液流电池可能是电网规模电存储的更好的解决方案。功率的独立缩放（取决于诸如电化学反应的动力学和电极表面积的影响）和能量（与罐的总尺寸，溶液中电解质的浓度和电离的程度有关）。电解液）为流动电池解决方案提供更灵活的工程设计。使用水作为溶剂进一步降低了安装成本并提高了操作安全性。因为它们可以来自石油和可持续生物物质，有机分子的巨大设计灵活性，以及​​它们有前途的性能，液体电池的有机电解质被认为是竞争对手（Kowalski等。2016年 ; Leung等。2017年 ; 魏等人。2017）。
#
# 高通量模拟，特别是与实验后续相结合，已成为发现有机液流电池电解质材料的有力工具。使用蒽醌二磺酸盐和溴/氢溴酸的酸性水溶液的高效，无金属，低成本流动电池设计的报告利用了数千个潜在醌分子的​​DFT计算，以优化negolyte及其水溶性的还原潜力（Huskinson）等人，2014）。允许通过苯并的域来识别有用的设计规则和结构-性能关系，naphto-理论预测，和蒽醌轴承13个的任何官能团的（的仔细分析铒等人2015年）。生物激发的苯醌醌衍生物的其他大量计算也确定了用于液流电池的潜在有用的电解质（Pineda Flores等人，2015）。
#
# 电解质基因组项目中使用的材料项目骨干上的一组从喹喔啉和蒽醌，thiane，噻吩衍生大多近5000分子进行高通量的计算，和联吡啶衍生物（Qu等人。2015年）。特别注意错误处理和氧化还原电位的估计，离子对解离和复盐形成。还报告了近1400种喹喔啉的非水流电池估算氧化还原电位，溶剂化能量和结构变化的详细分析（Cheng等人2015），以及4000多个具有一个或两个官能团的五元或六元环附件（Pelzer等人，2017年）。
#
# 还报告了一些规模较小的虚拟搜索。从在PubChem数据库可用实验报道分子开始，和下选择手动至315部署神经网络之后，提高观察到喹喔啉衍生物（Park等人的实验性能2015，2016）。
#
# 用于电化学应用的有机分子的化学稳定性影响电池的保质期和长期可循环性，是虚拟发现应用的常见问题之一。为此，已经使用DFT分析了锂离子电池的有机溶剂的第一次和第二次还原和氧化（Borodin等人，2015）。类似地，生物启发的咯嗪电解质已经通过实验证明，通过在虚拟搜索中包括稳定性标准，除了氧化还原和溶解度要求之外，在碱性含水液流电池中提供优异的稳定性（Lin等人，2016）。
#
# 已经报道了较少关注自动化和极高通量的方法，侧重于诸如对32种有机分子的低Li +结合亲和力（Park等人2011），15种镁电解质的抗衡离子（Qu等人2017），氧化还原- 可转换的聚合物基膜（Ward等人，2017），或调整有机分子的还原潜力，以优化小氧化还原活性分子与导电聚合物的组合（Araujo等人，2017）。
#
# HTVS还应用于与其他电化学应用相关的材料，如双层电容器（Schütter等人2016）或其他绿色化学应用，如可切换亲水性溶剂（R. Vanderveen等人，2015）。
#
# 4应用机器学习加速发现
# 与许多其他领域的情况一样，化学机器学习应用并不是一种新型企业（Pierce and Hohne 1986）。与许多其他应用中的情况一样，深度学习算法与较大数据集和专用计算硬件的组合已经导致机器学习的许多有效应用用于化学。
#
# 4.1定量结构 - 属性关系
# 机器学习到计算化学应用的大多数应用涉及在三维原子排列或化学图上建立快速统计代理到昂贵的计算。在某种意义上，这是建立在分子结构或3D几何上训练的定量结构 - 性质关系，通常使用分子力学在运行中生成。
#
# 同一出版物中的其他章节对最近对该领域的许多贡献进行了全面回顾，因此仅提供简要概述。我们鼓励读者在同一本书中进一步探索。
#
# 使用神经网络模型在潜在能量表面上进行插值的想法可以追溯到20世纪90年代（Blank等人1995）。将机器学习应用于计算化学的早期当代作品是Behler的那些，其中神经网络用于分子动力学模拟和其他PES探索技术（Behler 2011b，a ; Behler等人2007 ; Behler和Parrinello 2007）。神经网络的这些和许多其他应用，主要是批量和异质系统，最近已经被审查（Behler 2017）。
#
# 机器学习技术应用于计算化学的另一个应用领域，更重视分子，而不是大量材料最初利用核方法，重点是绘制3D坐标（Rupp等人2012 ;Schütt等人2017）或电子密度（Brockherde等人，2017年 ; Snyder等人，2012年）。这些方法在本出版物的其他章节中有详细介绍。
#
# 基于分子结构的预测中最重要的问题之一是选择代表分子的特征。化学家倾向于将分子视为无向图，节点中的原子和边缘中的键，以及立体化学的一些额外考虑因素。在量子化学中，分子是原子的三维排列，其对应于势能超曲面中的局部最小值。几十年来，化学信息学应用（主要是制药和药物发现）已经为两种图形的机器学习创建了描述性的丰富功能：药效团指纹，拓扑指纹以及3D构象。
#
# 最近机器学习对化学分子的应用主要集中在量子化学特性的QSPR上，并将重点放在更多信息丰富的特征上。例如，库仑矩阵是依赖于置换的对称不变修正距离矩阵。当代高度强大的神经网络方法也利用3D信息（Gilmer等人2017 ; Lubbers等人2017 ;Schütt等人2017年）。在三维结构未知的分子的情况下，这通常是在进行预测时的情况，这些特征是根据在理论的分子力学水平上即时计算的猜测几何计算的。分子力学方法通过潜在的力场进行了大量的参数化，通常是在量子化学计算上，但最终还是用于参数化的实验数据。因此，应用于这些特征的机器学习方法受到严格监督，其输入基本上定量地嵌入了大量的先前化学知识和手动调整。
#
# 由于图形同构，图形学习提出了一系列非常独特的挑战。图形结构上的机器学习方法比化学更受关注，例如在运输，数据库，电信等任何类型的网络中。而扩展连通性圆形指纹地址图同构，编码图形，散列，混淆化学信息的过程可以导致不同的化学子结构激活相同的特征。神经指纹是ECFP的一种可区分的深度学习扩展，最近被提出作为一种更灵活和可学习的替代方案（Duvenaud等人，2015）。这些化学拓扑指纹和衍生图形卷积的连续对应物（Kearnes等，2016已证明其优于QSPR的一些传统化学信息学描述符，特别是对于较大的数据集，并开辟了分子筛选的新途径。
#
# 4.2化学空间的搜索和优化
# 机器学习应用于计算化学/化学信息学界的一个有趣的子集正在由所有可能的分子或相关子集（例如具有芳环的小有机分子或类似子集）跨越的离散的高维空间中移动。出于兴趣。
#
# 化学空间非常大，估计数量级或数量级从10 23到10 60不等。据报道，基于规则的计算小分子化合物和彻底检测非实用但正式有效甚至可能稳定的分子的基于规则的努力如下：GDB-11列出了2640万个C，N，O最多11个原子的小有机分子。和F（Fink和Reymond 2007）; GDB-13列举了978亿个具有多达13个C，N，O，S和Cl原子的分子（Blum和Reymond 2009）; 和GDB-17含有1664亿个分子，最多17个C，N，O，S和卤素原子（Ruddigkeit等人，2012））。从这些集合推断出，药物化学空间的大小已推断为10 33（Polishchuk等人，2013年）。
#
# 除了空间的大小之外，分子是离散的图形，并且存在关于允许的连接类型和程度的规则。更进一步，正式有效的分子在感兴趣的温度，压力和时间尺度下仍可能是化学不稳定的。因此，进行局部甚至更具挑战性的全球优化对材料和药物设计非常感兴趣，也是一个巨大的挑战。化学空间项目利用GDB数据库开发可视化和探索工具，重点是候选药物分子（Reymond 2015）。
#
# 定制分子库已被证明是一种非常有效的化学空间导航方式，因为人为驱动的设计允许嵌入难以捕获的规则和化学要求，而无需强有力的监督，特别是关于分子的合成可接近性。这种成功反映在上一节中实例的实验适用性的简易性中。
#
# 该领域的多种机器学习方法表明，可以利用来自专利文献（Lowe 2012）或商业数据库的大量现有化学反应数据集来自动构建用于有机合成反应和反合成分析软件的反应性预测工具。最近的例子包括在对规则生成的例子进行训练之后预测反应物指纹的化学反应结果（Wei等人，2016），并通过对自生成候选者列表进行排序来选择主要产品（Coley等人，2017a ; Jin等人，2017）。遵循机器翻译方法的序列到序列模型（Fooshee等，2018; Schwaller等。2017）或相似性搜索（Coley等人，2017b）已被证明能够以自动，数据驱动的方式自动预测有机合成反应。从更大，更好的策划数据集中获得了更有希望的结果（Segler等人2017 ; Segler和Waller 2017a，b）。
#
# 一种众所周知的化学优化方法是遗传算法，其中来自手工制备的化学转化列表的突变并随机应用于起始分子，并且所得化合物（如果显示出所需性质的改善）保持用于进一步进化。因为它们依赖于手工挑选的突变和超参数，并且通常还依赖于目标属性之间的手动调整权衡，这些方法涉及一定程度的化学直觉。通过复合可以单独但不能组合使用的突变，产生的分子往往非常复杂。这些类型的遗传方法已被用于导航化学空间（van Deursen和Reymond 2007 ; Virshup等人2013）并优化多类分子，如有机发光二极管（Rupakheti等2016 ; Shu和Levine 2015），有机光伏（Kanal和Hutchison 2017），金刚石（Teunissen等2017），可见发色团高超极化率（Elward和Rinderspacher 2015），或具有高电偶极子的小分子（Rupakheti等，2015）。
#
# 4.3生成模型
# 生成模型是机器学习模型，旨在产生捕获训练群体的内在统计特性的自然表观数据。它们可以以无人监督的方式进行训练，因此不需要标记数据。鉴于化学空间的大小，以及已知的大量化学物质（见第2节），已知的化合物数量约为1亿，最近已经评估了基于现有分子的无监督深度学习模型。
#
# 化学中生成模型的最基本的例子之一是使用递归神经网络（RNN）来预测分子的SMILES表示的下一个特征（Voss 2015）。通过向网络提供n个字符来预测第n + 1个，已经证明RNN在生成有效的 - 如果是荒谬的 - 文本（Karpathy 2015）方面非常强大。可以存储单个字符串的简单而全面的分子字符串表示：简化的分子输入线路输入系统（SMILES）（Weininger 1988））。SMILES使用一系列规则和规范化程序包含完整的分子连接。事实证明，为文本显示的相同原理通过基于字符串的SMILES表示生成分子非常有效。另外的工作已经针对产生用于产生捕获训练数据的统计行为的引线的分子（Bjerrum 2017 ; Ertl等人2017 ; Gupta等人2017）。进一步的步骤涉及分子库的进化精制以使该组偏向给定的性质（Olivecrona等人2017）。
#
# 自动编码器是深度学习模型，经过训练可以再现高维输入，使其受到低维信息瓶颈的影响。分子设计中一些最棘手的问题来自分子的离散性和搜索域的极大尺寸。因此，这种低维，实值，可解码的嵌入可能允许将基于梯度的优化算法应用于分子优化。进一步的改进是使用变分自动编码器，其中随机噪声被添加到编码步骤，这导致潜在空间中更连续的覆盖以及更少的与有效解码点不对应的死区。
#
# 如上所述，存在使用化学图作为机器学习系统的输入的可用策略。然而，有效编写化学图的深度学习工具仍然是一个悬而未决的问题。神经网络架构已被证明可以有效地编写文本和图像，因此，第一份报告（Gómez-Bombarelli等人，2018年）用于化学发现的变分自动编码器（VAE）使用基于串的化学表示。这项工作展示了VAE如何从连续的实值阵列表示中精确地重建分子。更进一步，它探索了潜在空间中的变换，特别是关于感兴趣的性质的分子优化，如何进行。该应用在联合训练的VAE加预测系统的情况下特别有效，其中深度学习系统同时被训练为无监督发生器和监督预测器。在这种情况下，潜在空间在拓扑上受化学性质的影响（图2）。
# 在新窗口中打开图像图2
# 图2
# 具有联合属性预测的变分自动编码器的图表：编码器神经网络接收分子的串重复并将其转换为可通过解码的神经网络解码回字符串的实值数组。通过与属性预测网络联合训练，可以导航潜在空间以进行属性优化
#
# 最初的VAE模型存在几个缺陷，通常与其写出分子的能力有关，特别是字符串输出是概率性的。由于使用了字符串表示，并且需要内部一致性甚至算术（打开和关闭环和分支），VAE模型产生许多无效分子，不止一种意义上。一方面，语法错误导致字符串作为SMILES无效，并且不对应于实际化学图（打开但不关闭的循环，打开但不关闭的括号，表示未完成的分支等），a类似的失败是写出非化学有效图的完整图（通常与化合价和八位组合规则有关：化合价大于5的碳原子，化合价3的氧原子等）。
#
# 许多工作正在迅速扩展这一领域，解决这些性能问题，并探索化学中深层生成模型的进一步途径（Blaschke等人2017 ; Wang 2017）。这些包括使用SMILES的一系列语法规则作为解码器的输出（Kusner等人2017），主动学习输出的有效性（Janz等人2017），执行约束贝叶斯优化以避免探索死区潜在空间（Griffiths和Hernández-Lobato 2017），在编码潜点附近进行局部优化（Mueller等人，2017年）），结合额外的RNN，通过强化学习产生更高质量的产出（Jaques等，2016）。
#
# 已经报道了进一步改进和应用于产生DNA（Killoran等人2017）和蛋白质序列（Sinai等人2017），以及具有向所需特性施加偏差的能力的对抗性方法（Guimaraes等人2017 ; Sanchez） -Lengeling等人，2017）。
#
# 5结论
# 机器学习和数据驱动的应用程序风靡计算化学。由于采用了深度学习方法，几十年来被认为是圣杯的任务似乎比以往任何时候都更接近：符合或超越实验准确性的可负担的计算预测，可以击败人类的计算机化反向合成等。
#
# 特别是化学和计算化学，长期以来一直在努力研究高容量，高速度和高品种的数据。然而，痛点不同。在计算化学中，采集速度越来越不成为瓶颈。在实验上，它们对速度和再现性的限制更多，而且它们的成本要高得多。另一方面，计算化学已经显示出难以解决的变化：随着参数化增加了可转移性和对预测能力下降的信任。
#
# 它的数字化和自动化程度越高，实验化学物质就越多地与计算化学同化，因此最容易利用这些极具前景的数据驱动工具。为了产生更广泛的影响，如果计算化学确实是一个沙箱和最终改变实验化学的想法的加速器，则需要更多地关注异构的非结构化数据。无监督的机器学习和转移学习是这项任务的有前途的工具。
#
# 笔记
# 致谢
# AAG感谢能源部，基础能源科学办公室的支持de sc0015959。他还感谢AndersFrøseth博士对这项工作的慷慨支持。RGB承认丰田职业发展主席提供财务支持。
#
# 参考
# Álvarez-Moreno M，de Graaf C，LópezN，Maseras F，Poblet JM，Bo C（2015）管理计算化学大数据问题：ioChem-BD平台。J Chem Inf Model 55:95
# CrossRef Google学术搜索
# Araujo RB，Banerjee A，Panigrahi P，Yang L，StrømmeM，SjödinM，Araujo CM，Ahuja R（2017）设计策略调整有机分子的还原潜力，以实现可持续的高容量电池应用。J Mater Chem A 5：4430
# CrossRef Google学术搜索
# Behler J（2011a）以原子为中心的对称函数，用于构建高维神经网络势。J Chem Phys 134：74106
# CrossRef Google学术搜索
# Behler J（2011b）神经网络势能 - 化学中的能量表面：用于大规模模拟的工具。Phys Chem Chem Phys 13：17930
# CrossRef Google学术搜索
# Behler J（2017）第一原理神经网络潜力用于大分子和浓缩系统的反应模拟。Angew Chemie Int Ed 56：12828
# CrossRef Google学术搜索
# Behler J，Lorenz S，Reuter K（2007）代表与对称适应神经网络的分子 - 表面相互作用。J Chem Phys 127：14705
# ADS CrossRef Google学术搜索
# Behler J，Parrinello M（2007）高维势能面的广义神经网络表示。Phys Rev Lett 98：146401
# ADS CrossRef Google学术搜索
# Belsky A，Hellenbrandt M，Karen VL，Luksch P（2002）无机晶体结构数据库（ICSD）的新发展：支持材料研究和设计的可达性。Acta Crystallogr Sect B Struct Sci 58：364
# CrossRef Google学术搜索
# Berman HM，Westbrook J，Feng Z，Gilliland G，Bhat TN，Weissig H，Shindyalov IN，Bourne PE（2000）The protein data bank。Nucleic Acids Res 28：235
# CrossRef Google学术搜索
# Bernstein FC，Koetzle TF，Williams GJB，Meyer EF，Brice MD，Rodgers JR，Kennard O，Shimanouchi T，Tasumi M（1978）蛋白质数据库：用于大分子结构的基于计算机的档案文件。Arch Biochem Biophys 185：584
# CrossRef Google学术搜索
# Bjerrum EJ（2017）SMILES枚举作为神经网络建模的数据增强分子Arxiv.Org
# Google Scholar
# 空白TB，Brown SD，Calhoun AW，Doren DJ（1995）势能面的神经网络模型。J Chem Phys 103：4129
# ADS CrossRef Google学术搜索
# Blaschke T，Olivecrona M，Engkvist O，Bajorath J，Chen H（2017）生成自动编码器在de Novo分子设计中的应用。通知
# Google学术搜索
# Block P，Sotriffer CA，Dramburg I，Klebe G（2006）AffinDB：来自PDB的蛋白质 - 配体复合物亲和力的可自由访问的数据库。Nucleic Acids Res 34：D522
# CrossRef Google学术搜索
# Blum LC，Reymond JL（2009）在化学宇宙数据库GDB-13中用于虚拟筛选的9.7亿个类似药物的小分子。J Am Chem Soc 131：8732
# CrossRef Google学术搜索
# Borodin O，Olguin M，Spear CE，Leiter KW，Knap J（2015）迈向高通量筛选电池电解质的电化学稳定性。纳米技术26：354003
# CrossRef Google学术搜索
# Brockherde F，Vogt L，Li L，Tuckerman ME，Burke K，MüllerKR（2017）用机器学习绕过Kohn-Sham方程。Nat Commun 8：872
# ADS CrossRef Google学术搜索
# Bruno I，GražulisS，Helliwell JR，Kabekkodu SN，McMahon B，Westbrook J（2017）Crystallography and databases。Data Sci J 16
# Google学术搜索
# Calderon CE，Plata JJ，Toher C，Oses C，Levy O，Fornari M，Natan A，Mehl MJ，Hart G，Buongiorno Nardelli M，Curtarolo S（2015）AFLOW高通量材料科学计算标准。Comput Mater Sci 108：233
# CrossRef Google学术搜索
# Chambers J，Davies M，Gaulton A，Hersey A，Velankar S，Petryszak R，Hastings J，Bellis L，McGlinchey S，Overington JP（2013）UniChem：统一的化学结构交叉参考和标识符跟踪系统。J Cheminform 5：3
# CrossRef Google学术搜索
# Chen X，Liu M，Gilson MK（2001）BindingDB：一种可通过网络访问的分子识别数据库。Comb Chem High Throughput Screen 4：719
# CrossRef Google学术搜索
# Cheng L，Assary RS，Qu X，Jain A，Ong SP，Rajput NN，Persson K，Curtiss LA（2015）利用高通量筛选加速储能电解质的发现。J Phys Chem Lett 6：283
# CrossRef Google学术搜索
# Chmiela S，Tkatchenko A，Sauceda HE，Poltavsky I，SchüttKT，MüllerKR（2017）精确节能分子力场的机器学习。Sci Adv 3：e1603015
# ADS CrossRef Google学术搜索
# Coley CW，Barzilay R，Jaakkola TS，Green WH，Jensen KF（2017a）使用机器学习预测有机反应结果。ACS Cent Sci 3：434
# CrossRef Google学术搜索
# Coley CW，Rogers L，Green WH，Jensen KF（2017b）基于分子相似性的计算机辅助反合成。ACS Cent Sci 3：1237
# CrossRef Google学术搜索
# Curtarolo S，Setyawan W，Hart GLW，Jahnatek M，Chepulskii RV，Taylor RH，Wang S，Xue J，Yang K，Levy O，Mehl MJ，Stokes HT，Demchenko DO，Morgan D（2012a）AFLOW：一个自动框架高通量材料发现。Comput Mater Sci 58：218
# CrossRef Google学术搜索
# Curtarolo S，Setyawan W，Wang S，Xue J，Yang K，Taylor RH，Nelson LJ，Hart GLW，Sanvito S，Buongiorno-Nardelli M，Mingo N，Levy O（2012b）AFLOWLIB.ORG：a distributed materials properties repository from高通量从头计算。Comput Mater Sci 58：227
# CrossRef Google学术搜索
# Davis AP，Grondin CJ，Johnson RJ，Sciaky D，King BL，McMorran R，Wiegers J，Wiegers TC，Mattingly CJ（2017）The comparison toxicogenomics database：update 2017.Nucleic Acids Res 45：D972
# CrossRef Google Scholar
# Degtyarenko K，de Matos P，Ennis M，Hastings J，Zbinden M，McNaught A，AlcántaraR，Darsow M，Guedj M，Ashburner M（2008）ChEBI：生物学感兴趣的化学实体的数据库和本体。Nucleic Acids Res 36：D344
# CrossRef Google学术搜索
# Ding H，Medasani B，Chen W，Persson KA，Haranczyk M，Asta M（2015）PyDII：用于计算金属间化合物中的平衡本征点缺陷浓度和外在溶质位点偏好的python框架。Comput Phys Commun 193：118
# ADS CrossRef Google学术搜索
# Duvenaud DK，Maclaurin D，Aguilera-Iparraguirre J，Gómez-Bombarelli R，Hirzel T，Aspuru-Guzik A，Adams RP，Iparraguirre J，Bombarell R，Hirzel T，Aspuru-Guzik A，Adams RP（2015）Adv Neural Inf Process Syst 2：2215-2223
# Google学术搜索
# Elward JM，Rinderspacher BC（2015）在复杂化学子空间上进行平滑启发式优化。Phys Chem Chem Phys 17：24322
# CrossRef Google学术搜索
# Er S，Suh C，Marshak MP，Aspuru-Guzik A（2015）全醌氧化还原液流电池分子的计算设计。Chem Sci 6：885
# CrossRef Google学术搜索
# Ertl P，Lewis R，Martin E，Polyakov V（2017）使用LSTM神经网络计算机生成新型药物化学物质Arxiv.Org
# Google Scholar
# Faber J, Fawcett T, IUCr (2002) The powder diffraction file: present and future. Acta Crystallogr Sect B Struct Sci 58:325
# CrossRefGoogle Scholar
# Feller D (1996) The role of databases in support of computational chemistry calculations. J Comput Chem 17:1571
# CrossRefGoogle Scholar
# Fink T, Reymond JL (2007) Virtual exploration of the chemical universe up to 11 atoms of C, N, O, F: assembly of 26.4 million structures (110.9 million stereoisomers) and analysis for new ring systems, stereochemistry, physicochemical properties, compound classes, and drug discove. J Chem Inf Model 47:342
# CrossRefGoogle Scholar
# Fooshee D, Mood A, Gutman E, Tavakoli M, Urban G, Liu F, Huynh N, Van Vranken D, Baldi P (2018) Deep learning for chemical reaction prediction. Mol Syst Des Eng
# Google Scholar
# Gaulton A, Bellis LJ, Bento AP, Chambers J, Davies M, Hersey A, Light Y, McGlinchey S, Michalovich D, Al-Lazikani B, Overington JP (2012) ChEMBL: a large-scale bioactivity database for drug discovery. Nucleic Acids Res 40:D1100
# CrossRefGoogle Scholar
# Gilmer J, Schoenholz SS, Riley PF, Vinyals O, Dahl GE (2017) Neural message passing for quantum chemistry. arXiv1704.01212 [Cs]
# Google Scholar
# Gilson MK, Liu T, Baitaluk M, Nicola G, Hwang L, Chong J (2016) BindingDB in 2015: a public database for medicinal chemistry, computational chemistry and systems pharmacology. Nucleic Acids Res 44:D1045
# CrossRefGoogle Scholar
# Goldsmith B (2016) NoMaD repository entry
# Google Scholar
# Gómez-Bombarelli R, Aguilera-Iparraguirre J, Hirzel TD, Duvenaud D, Maclaurin D, Blood-Forsythe MA, Chae HS, Einzinger M, Ha D-G, Wu T, Markopoulos G, Jeon S, Kang H, Miyazaki H, Numata M, Kim S, Huang W, Hong SI, Baldo M, Adams RP, Aspuru-Guzik A (2016) Design of efficient molecular organic light-emitting diodes by a high-throughput virtual screening and experimental approach. Nat Mater 15:1120
# ADSCrossRefGoogle Scholar
# Gómez-Bombarelli R, Wei JN, Duvenaud D, Hernández-Lobato JM, Sánchez-Lengeling B, Sheberla D, Aguilera-Iparraguirre J, Hirzel TD, Adams RP, Aspuru-Guzik A (2018) Automatic chemical design using a data-driven continuous representation of molecules. ACS Cent Sci 4:268
# CrossRefGoogle Scholar
# Goyal A, Gorai P, Peng H, Lany S, Stevanović V (2017) A computational framework for automation of point defect calculations. Comput Mater Sci 130:1
# CrossRefGoogle Scholar
# Gražulis S, Chateigner D, Downs RT, Yokochi AFT, Quirós M, Lutterotti L, Manakova E, Butkus J, Moeck P, Le Bail A (2009) Crystallography open database – an open-access collection of crystal structures. J Appl Crystallogr 42:726
# CrossRefGoogle Scholar
# Gražulis S, Daškevič A, Merkys A, Chateigner D, Lutterotti L, Quirós M, Serebryanaya NR, Moeck P, Downs RT, Le Bail A (2012) Crystallography Open Database (COD): an open-access collection of crystal structures and platform for world-wide collaboration. Nucleic Acids Res 40:D420
# CrossRefGoogle Scholar
# Griffiths R-R, Hernández-Lobato JM (2017) Constrained bayesian optimization for automatic chemical design. ArXiv:1709.05501
# Google Scholar
# Groom CR, Bruno IJ, Lightfoot MP, Ward SC, IUCr (2016) The Cambridge structural database. Acta Crystallogr Sect B Struct Sci Cryst Eng Mater 72:171
# CrossRefGoogle Scholar
# Guimaraes GL, Sanchez-Lengeling B, Outeiral C, Farias PLC, Aspuru-Guzik A (2017) Objective-Reinforced Generative Adversarial Networks (ORGAN) for sequence generation models. ArXiv:1705.10843
# Google Scholar
# Gupta A, Müller AT, Huisman BJH, Fuchs JA, Schneider P, Schneider G (2017) Generative recurrent networks for De Novo drug design. Mol Inf
# Google Scholar
# Hachmann J, Olivares-Amaya R, Atahan-Evrenk S, Amador-Bedolla C, Sanchez-Carrera RS, Gold-Parker A, Vogt L, Brockway AM, Aspuru-Guzik A (2011) The Harvard clean energy project: large-scale computational screening and design of organic photovoltaics on the world community grid. J Phys Chem Lett 2:2241
# CrossRefGoogle Scholar
# Hachmann J, Olivares-Amaya R, Jinich A, Appleton AL, Blood-Forsythe MA, Seress LR, Roman-Salgado C, Trepte K, Atahan-Evrenk S, Er S, Shrestha S, Mondal R, Sokolov A, Bao Z, Aspuru-Guzik A (2014) Lead candidates for high-performance organic photovoltaics from high-throughput quantum chemistry – the Harvard Clean Energy Project. Energy Environ Sci 7:698
# CrossRefGoogle Scholar
# Heifets A, Jurisica I (2012) SCRIPDB: a portal for easy access to syntheses, chemicals and reactions in patents. Nucleic Acids Res 40:D428
# CrossRefGoogle Scholar
# Hermann G, Pohl V, Tremblay JC, Paulus B, Hege H-C, Schild A (2016) ORBKIT: a modular python toolbox for cross-platform postprocessing of quantum chemical wavefunction data. J Comput Chem 37:1511
# CrossRefGoogle Scholar
# Hjorth Larsen A, Jørgen Mortensen J, Blomqvist J, Castelli IE, Christensen R, Dułak M, Friis J, Groves MN, Hammer B, Hargus C, Hermes ED, Jennings PC, Bjerre Jensen P, Kermode J, Kitchin JR, Leonhard Kolsbjerg E, Kubal J, Kaasbjerg K, Lysgaard S, Bergmann Maronsson J, Maxson T, Olsen T, Pastewka L, Peterson A, Rostgaard C, Schiøtz J, Schütt O, Strange M, Thygesen KS, Vegge T, Vilhelmsen L, Walter M, Zeng Z, Jacobsen KW (2017) The atomic simulation environment – a Python library for working with atoms. J Phys Condens Matter 29:273002
# CrossRefGoogle Scholar
# Holliday GL, Bartlett GJ, Almonacid DE, O’Boyle NM, Murray-Rust P, Thornton JM, Mitchell JBO (2005) MACiE: a database of enzyme reaction mechanisms. Bioinformatics 21:4315
# CrossRefGoogle Scholar
# Huskinson B, Marshak MP, Suh C, Er S, Gerhardt MR, Galvin CJ, Chen X, Aspuru-Guzik A, Gordon RG, Aziz MJ (2014) A metal-free organic-inorganic aqueous flow battery. Nature 505:195
# ADSCrossRefGoogle Scholar
# Russel D. Johnson II (1999) Computational chemistry comparison and benchmark database. NIST Standard Reference Database Number 101 Release 18, Oct 2016
# Google Scholar
# Jacob CR, Beyhan SM, Bulo RE, Gomes ASP, Götz AW, Kiewisch K, Sikkema J, Visscher L (2011) PyADF - A scripting framework for multiscale quantum chemistry. J Comput Chem 32:2328
# CrossRefGoogle Scholar
# Jain A, Ong SP, Hautier G, Chen W, Richards WD, Dacek S, Cholia S, Gunter D, Skinner D, Ceder G, Persson KA (2013) Commentary: the materials project: a materials genome approach to accelerating materials innovation. APL Mater 1:11002
# ADSCrossRefGoogle Scholar
# Janz D, van der Westhuizen J, Hernández-Lobato JM (2017) Actively learning what makes a discrete sequence valid. ArXiv:1708.04465
# Google Scholar
# Jaques N, Gu S, Bahdanau D, Hernández-Lobato JM, Turner RE, Eck D (2016) Sequence Tutor: conservative Fine-Tuning of Sequence Generation Models with KL-control Proceedings.Mlr.Press
# Google Scholar
# Jin W, Coley C, Barzilay R, Jaakkola T (2017) Predicting organic reaction outcomes with Weisfeiler-Lehman network ArXiv:1709.04555 2604
# Google Scholar
# Kaiser J（2005）科学资源。化学家希望NIH缩减数据库。Science 308：774
# CrossRef Google学术搜索
# Kanal IY，Hutchison GR（2017）使用遗传算法快速计算分子特性：在数百万种化合物中搜索有机光伏材料ArXiv：1707.02949 [物理学]
# Google学术搜索
# Karpathy A（2015）
# Google学术搜索
# Kearnes S，McCloskey K，Berndl M，Pande V，Riley P（2016）Molecular graph convolutions：moving beyond fingerprintprints。J Comput Aided Mol Des 30：595
# ADS CrossRef Google学术搜索
# Killoran N，Lee LJ，Delong A，Duvenaud D，Frey BJ（2017）使用深度生成模型生成和设计DNA ArXiv：1712.06148
# Google Scholar
# Kirklin S，Saal JE，Meredig B，Thompson A，Doak JW，Aykol M，RühlS，Wolverton C（2015）开放量子材料数据库（OQMD）：评估DFT形成能量的准确性。Npj Comput Mater 1：15010
# ADS CrossRef Google学术搜索
# Klintenberg M，Derenzo SE，Weber MJ（2002）通过电子结构计算确定的潜在闪烁体。Nucl Instruments Methods Phys Res Sect A Accel Spectrometers，Detect Assoc Equip 486：298
# ADS CrossRef Google Scholar
# Kowalski JA，Su L，Milshtein JD，Brushett FR（2016）用于非水液流电池的氧化还原活性有机分子的分子工程的最新进展。Curr Opin Chem Eng 13:45
# CrossRef Google学术搜索
# Kusner MJ，Paige B，Hernández-Lobato JM（2017）Grammar variational autoencoder arXiv：1703.01925 [Stat]
# Google Scholar
# Landis DD，Hummelshoj JS，Nestorov S，Greeley J，Dulak M，Bligaard T，Norskov JK，Jacobsen KW（2012）The Computational materials repository。Comput Sci Eng 14:51
# CrossRef Google学术搜索
# Leung P，Shah AA，Sanz L，Flox C，Morante JR，Xu Q，Mohamed MR，PoncedeLeónC，Walsh FC（2017）有机氧化还原液流电池的最新发展：一篇评论性评论。J Power Sources 360：243
# CrossRef Google学术搜索
# Lin L（2015）通过第一原理计算构建的材料数据库基础设施：审查。Mater Perform Charact 4：MPC20150014
# CrossRef Google学术搜索
# Lin K，Gómez-Bombarelli R，Beh ES，Tong L，Chen Q，Valle A，Aspuru-Guzik A，Aziz MJ，Gordon RG（2016）具有基于alloxazine的有机电解质的氧化还原液流电池。Nat Energy 1：16102
# ADS CrossRef Google学术搜索
# Linstrom PJ，Mallard WG（2001）NIST Chemistry WebBook：互联网上的化学数据资源。J Chem Eng Data 46：1059
# CrossRef Google学术搜索
# Liu Z，Li Y，Han L，Li J，Liu J，Zhao Z，Nie W，Liu Y，Wang R（2015）PDB范围的绑定数据集合：PDBbind数据库的当前状态。Bioinformatics 31：405
# CrossRef Google学术搜索
# Lopez SA，Pyzer-Knapp EO，Simm GN，Lutzow T，Li K，Seress LR，Hachmann J，Aspuru-Guzik A（2016）The Harvard organic photovoltaic dataset。Sci Data 3：160086
# CrossRef Google学术搜索
# Lopez SA，Sanchez-Lengeling B，de Goes Soares J，Aspuru-Guzik A（2017）设计原则和顶级非富勒烯受体候选者，用于有机光伏。Joule 1：857
# CrossRef Google学术搜索
# Lowe DM（2012）从文献中提取化学结构和反应。剑桥大学博士论文，博士，3656，https： //doi.org/10.17863/CAM.16293
# Lubbers N，Smith JS，Barros K（2017）使用深度神经网络对分子能量进行分层建模。J Chem Phys 148：241715
# ADS CrossRef Google学术搜索
# Martsinovich N，Troisi A（2011）用于染料敏化太阳能电池的发色团的高通量计算筛选。J Phys Chem C 115：11781
# CrossRef Google学术搜索
# Mattingly CJ，Colby GT，Forrest JN，Boyer JL（2003）The Comparative Toxicogenomics Database（CTD）。Environ Health Perspect 111：793
# CrossRef Google学术搜索
# Mayeshiba T，Wu H，Angsten T，Kaczmarowski A，Song Z，Jenness G，Xie W，Morgan D（2017）MAterials Simulation Toolkit（MAST）用于缺陷和扩散的原子建模。Comput Mater Sci 126：90
# CrossRef Google学术搜索
# Merkys A，Mounet N，Cepellotti A，Marzari N，GražulisS，Pizzi G（2017）来自自动起源跟踪的后验元数据：AiiDA和TCOD的集成ArXiv：1706.08704
# Google Scholar
# Meyer EF（1997）蛋白质数据库的第一年。Protein Sci 6：1591
# CrossRef Google Scholar
# Mueller J，Gifford D，Jaakkola T（2017）序列更好的序列：连续修订组合结构。ICML 70：2536
# Google学术搜索
# Nakata M，Shimazaki T（2017）PubChemQC项目：用于数据驱动化学的大规模第一原理电子结构数据库。J Chem Inf Model 57：1300
# CrossRef Google学术搜索
# Nath SR，Kurup SS，Joshi KA（2016）PyGlobal：用于自动编译基于DFT的描述符的工具包。J Comput Chem 37：1505
# CrossRef Google学术搜索
# O'boyle NM，Tenderholt AL，Langner KM（2008）cclib：用于独立于封装的计算化学算法的库。J Comput Chem 29：839
# CrossRef Google学术搜索
# Olivares-Amaya R，Amador-Bedolla C，Hachmann J，Atahan-Evrenk S，Sanchez-Carrera RS，Vogt L，Aspuru-Guzik A（2011）通过化学信息学加速计算发现有机光伏的高性能材料。Energy Environ Sci 4：4849
# CrossRef Google学术搜索
# Olivecrona M，Blaschke T，Engkvist O，Chen H（2017）Molecular De Novo Design通过Deep Reinforcement Learning Arxiv.Org
# Google Scholar
# Ong SP，Richards WD，Jain A，Hautier G，Kocher M，Cholia S，Gunter D，Chevrier VL，Persson KA，Ceder G（2013）Python Materials Genomics（pymatgen）：用于材料分析的强大的开源python库COMPUT。Comput Mater Sci 68：314
# CrossRef Google学术搜索
# Ong SP，Cholia S，Jain A，Brafman M，Gunter D，Ceder G，Persson KA（2015）材料应用程序编程接口（API）：基于REpresentational State Transfer（REST）的简单，灵活和高效的材料数据API原则。Comput Mater Sci 97：209
# CrossRef Google学术搜索
# ØrnsøKB，Pedersen CS，Garcia-Lastra JM，Thygesen KS（2014）使用大规模ab initio计算优化染料敏化太阳能电池的卟啉。Phys Chem Chem Phys 16：16246
# CrossRef Google学术搜索
# Ortiz C，Eriksson O，Klintenberg M（2009）数据挖掘和加速电子结构理论作为寻找新功能材料的工具Comput。Comput Mater Sci 44：1042
# CrossRef Google学术搜索
# Pampel H，Vierkant P，Scholze F，Bertelmann R，Kindling M，Klump J，Goebelbecker HJ，Gundlach J，Schirmbacher P，Dierolf U（2013）使研究数据库可见：re3data.org注册表。PLoS One 8：e78080
# ADS CrossRef Google学术搜索
# Papadatos G，Davies M，Dedman N，Chambers J，Gaulton A，Siddle J，Koks R，Irvine SA，Pettersson J，Goncharoff N，Hersey A，Overington JP（2016）SureChEMBL：一个大规模，化学注释的专利文献数据库。Nucleic Acids Res 44：D1220
# CrossRef Google学术搜索
# Park MH，Lee YS，Lee H，Han YK（2011）Low Li +结合亲和力：添加剂在锂离子电池中形成固体电解质界面的重要特征。J Power Sources 196：5109
# CrossRef Google学术搜索
# Park MS，Kang YS，Im D（2015）一种高速筛选方法，结合高通量方法和机器学习算法，用于开发可充电电池中的新型有机电解质。ECS Trans 68:75
# CrossRef Google学术搜索
# Park MS，Park I，Kang YS，Im D，Doo SG，Sik Park M，Park I，Kang YS，Im D，Doo SG（2016）适用于高压可充电电池的有机添加剂和溶剂的搜索图。Phys Chem Chem Phys 18：26807
# CrossRef Google学术搜索
# Pelzer KM，Cheng L，Curtiss LA（2017）功能基团在氧化还原活性有机分子中的作用：高通量筛选方法。J Phys Chem C 121：237
# CrossRef Google学术搜索
# Pence HE，Williams A（2010）ChemSpider：一种在线化学信息资源。J Chem Educ 87：1123
# CrossRef Google学术搜索
# Pierce TH，Hohne BA（eds）（1986）化学中的人工智能应用（美国化学学会）。华盛顿特区
# Google学术搜索
# Pineda Flores SD，Martin-Noble GC，Phillips RL，Schrier J（2015）用于水性氧化还原液流电池的生物活性电活性有机分子。1苯硫醌。J Phys Chem C 119：21800
# CrossRef Google学术搜索
# Pizzi G，Cepellotti A，Sabatini R，Marzari N，Kozinsky B（2016）AiiDA：自动交互式基础设施和计算科学数据库。Comput Mater Sci 111：218
# CrossRef Google学术搜索
# Polishchuk PG，Madzhidov TI，Varnek A（2013）基于GDB-17数据估算类药物化学空间的大小。J Comput Aided Mol Des 27：675
# ADS CrossRef Google学术搜索
# Pyzer-Knapp EO，Suh C，Gómez-Bombarelli R，Aguilera-Iparraguirre J，Aspuru-Guzik AA，Gomez-Bombarelli R，Aguilera-Iparraguirre J，Aspuru-Guzik AA，Clarke DR（2015）什么是高通量虚拟筛选？从有机材料发现的角度来看。Annu Rev Mater Res 45：195
# ADS CrossRef Google学术搜索
# Pyzer-Knapp EO，Simm GN，Aspuru Guzik A（2016）贝叶斯方法，用于校准高通量虚拟筛选结果并应用于有机光伏材料。Mater Horizo​​ns 3：226
# CrossRef Google学术搜索
# Qu X，Jain A，Rajput NN，Cheng L，Zhang Y，Ong SP，Brafman M，Maginn E，Curtiss LA，Persson KA（2015）The Electrolyte Genome项目：电池材料发现的大数据方法。Comput Mater Sci 103：56
# CrossRef Google学术搜索
# Qu X，Zhang Y，Rajput NN，Jain A，Maginn E，Persson KA（2017）新型镁电解质的计算设计，具有改进的性能。J Phys Chem C 121：16126
# CrossRef Google学术搜索
# Ramakrishnan R，Dral PO，Rupp M，von Lilienfeld OA（2014）量子化学结构和134千分子的性质。Sci Data 1：140022
# CrossRef Google学术搜索
# Reymond JL（2015）化学空间项目。Acc Chem Res 48：722
# CrossRef Google学术搜索
# Ruddigkeit L，van Deursen R，Blum LC，Reymond JL（2012）在化学宇宙数据库GDB-17中计算了166亿个有机小分子。J Chem Inf Model 52：2864
# CrossRef Google学术搜索
# Rupakheti C，Virshup A，Yang W，Beratan DN（2015）发现小分子宇宙中多样化最佳分子的策略。J Chem Inf Model 55：529
# CrossRef Google学术搜索
# Rupakheti C，Al-Saadon R，Zhang Y，Virshup AM，Zhang P，Yang W，Beratan DN（2016）用于有机发光二极管的多种最佳分子库。J Chem Theory Comput 12：1942
# CrossRef Google学术搜索
# Rupp M，Tkatchenko A，MüllerKR，von Lilienfeld OA（2012）利用机器学习快速准确地建模分子雾化能量。Phys Rev Lett 108：58301
# ADS CrossRef Google学术搜索
# Sanchez-Lengeling B，Outeiral C，Guimaraes GL，Aspuru-Guzik A（2017）优化分子空间上的分布。反向设计化学的客观强化生成对抗网络（ORGANIC）ChemRxiv 1
# Google Scholar
# Schuchardt KL，Didier BT，Elsethagen T，Sun L，Gurumoorthi V，Chase J，Li J，Windus TL（2007）Basis set exchange：计算科学的社区数据库。J Chem Inf Model 47：1045
# CrossRef Google学术搜索
# SchüttKT，Arbabzadah F，Chmiela S，MüllerKR，Tkatchenko A（2017）来自深张量神经网络的量子化学见解。Nat Commun 8：13890
# ADS CrossRef Google学术搜索
# SchütterC，Husch T，Viswanathan V，Passerini S，Balducci A，Korth M（2016）合理设计用于电化学双层电容器的新电解质材料。J Power Sources 326：541
# CrossRef Google学术搜索
# Schwaller P，Gaudin T，Lanyi D，Bekas C，Laino T（2017）发现：使用神经序列 - 序列模型预测复杂有机化学反应的结果。arXiv：1711.04810
# Google学术搜索
# Segler MHS，Waller MP（2017a）模拟化学推理来预测和发明反应。Chem A Eur J 23：6118
# CrossRef Google学术搜索
# Segler MHS，Waller MP（2017b）用于反复合成和反应预测的神经符号机器学习。Chem A Eur J 23：5966
# CrossRef Google学术搜索
# Segler MHS，Preuss M，Waller MP（2017）学习计划化学合成ArXiv：1708.04202
# Google Scholar
# Shin Y，Liu J，Quigley JJ，Luo H，Lin X（2014）用于本体异质结太阳能电池的共聚物供体材料的组合设计。ACS Nano 8：6089
# CrossRef Google学术搜索
# Shu Y，Levine BG（2015）用于发光二极管的荧光团的模拟演变。J Chem Phys 142：104104
# ADS CrossRef Google学术搜索
# Sinai S，Kelsic E，Church GM，Nowak MA（2017）蛋白质序列的变异自动编码。Arxiv.org 1
# Google学术搜索
# Smith JS，Isayev O，Roitberg AE（2017）ANI-1，一组2000万计算的有机分子非平衡构象。Sci Data 4：170193
# CrossRef Google学术搜索
# Snyder JC，Rupp M，Hansen K，MüllerKR，Burke K（2012）利用机器学习寻找密度函数。Phys Rev Lett 108：253002
# ADS CrossRef Google学术搜索
# Teunissen JL，De Proft F，De Vleeschouwer F（2017）使用逆分子设计调整小金刚石的HOMO-LUMO能隙。J Chem Theory Comput 13：1351
# CrossRef Google学术搜索
# Thygesen KS，Jacobsen KW（2016）充分利用材料计算。Science 354：180
# ADS CrossRef Google学术搜索
# van Deursen R，Reymond JL（2007）化学太空旅行。Chem Med Chem 2：636
# CrossRef Google学术搜索
# Vanderveen JR，Patiny L，Chalifoux CB，Jessop MJ，Jessop PG，Vanderveen JR，Patiny L，Chalifoux CB，Jessop MJ，Jessop PG（2015）用于识别最环保化合物的虚拟筛选方法：应用于可切换亲水性溶剂。Green Chem 17：5182
# CrossRef Google学术搜索
# Virshup AM，Contreras-GarcíaJ，Wipf P，Yang W，Beratan DN（2013）随机航行到未知的化学空间，产生了所有可能的药物样化合物的代表性库。J Am Chem Soc 135：7296
# CrossRef Google学术搜索
# Voss C（2015）用递归神经网络建模分子
# Google Scholar
# Waller MP，Dresselhaus T，Yang J（2013）JACOB：计算化学的企业框架。J Comput Chem 34：1420
# CrossRef Google学术搜索
# Wang S（2017）Seq2seq指纹图谱：用于药物发现的无监督深层分子嵌入。Dl.acm.org 285
# Google学术搜索
# Wang R，Fang X，Lu Y，Wang S（2004）PDBbind数据库：具有已知三维结构的蛋白质 - 配体复合物的结合亲和力的集合。J Med Chem 47：2977
# CrossRef Google学术搜索
# Ward AL，Doris SE，Li L，Hughes MA，Qu X，Persson KA，Helms BA（2017）材料基因组学筛选适用于锂 - 硫电池中的redox-Switchable微孔聚合物膜的自适应离子传输行为。ACS Cent Sci 3：399
# CrossRef Google学术搜索
# Wei JN，Duvenaud D，Aspuru-Guzik A（2016）用于预测有机化学反应的神经网络。ACS Cent Sci 2：725
# CrossRef Google学术搜索
# Wei X，Pan W，Duan W，Hollas A，Yang Z，Li B，Nie Z，Liu J，Reed D，Wang W，Sprenkle V（2017）有机氧化还原液流电池的材料和系统：现状和挑战。ACS Energy Lett 2：2187
# CrossRef Google学术搜索
# Weininger D（1988）SMILES，一种化学语言和信息系统。1.方法和编码规则简介。J Chem Inf Model 28:31
# CrossRef Google学术搜索
# Wishart DS，Knox C，Guo AC，Shrivastava S，Hassanali M，Stothard P，Chang Z，Woolsey J（2006）DrugBank：一种用于计算机药物发现和探索的综合资源。Nucleic Acids Res 34：D668
# CrossRef Google学术搜索
# Wishart DS，Feunang YD，Guo AC，Lo EJ，Marcu A，Grant JR，Sajed T，Johnson D，Li C，Sayeeda Z，Assempour N，Iynkkaran I，Liu Y，Maciejewski A，Gale N，Wilson A，Chin L ，Cummings R，Le D，Pon A，Knox C，Wilson M（2018）DrugBank 5.0：2018年DrugBank数据库的主要更新.Nucleic Acids Res 46：D1074
# CrossRef Google Scholar
# Yuan G，Gygi F（2010）ESTEST：电子结构代码验证和验证的框架。Comput Sci Discov 3：15004
# CrossRef Google学术搜索
# 版权信息
# ©Springer International Publishing AG，Springer Nature 2018的一部分
# 部门编辑和附属机构
# Nicola Marzari1
# 1. 瑞士洛桑瑞士联邦理工学院材料理论与模拟实验室
# 关于此条目
# CROSSMARK
# 引用此条目为：
# Gómez-Bombarelli R., Aspuru-Guzik A. (2018) Machine Learning and Big-Data in Computational Chemistry. In: Andreoni W., Yip S. (eds) Handbook of Materials Modeling. Springer, Cham
# Received
# 22 January 2018
#  Accepted
# 01 June 2018
# First Online
# 10 July 2018
#  DOI
# https://doi.org/10.1007/978-3-319-42913-7_59-1
# Publisher Name
# Springer, Cham
#  Online ISBN
# 978-3-319-42913-7
# eBook Packages
# Physics and Astronomy
# Reprints and Permissions
# 机器学习与计算化学中的大数据
#
# 引用 条目
# 怎么引用？
# .RIS
# 论文
# 参考经理
# RefWorks
# Zotero
# .ENW
# EndNote
# .BIB
# BibTeX
# JabRef
# Mendeley
# Actions
# Over 10 million scientific documents at your fingertips
#
#
# Academic Edition
# Corporate Edition
# Home Impressum Legal information Privacy statement How we use cookies Accessibility Contact us
# Springer Nature
# © 2018 Springer Nature Switzerland AG. Part of Springer Nature.
#
# 未登入 东吴大学图书馆（3000131270） - 5102 SpringerLink China OAC National Consortium（3000202650） - 7217 SpringerLink江苏电子书联盟2010-2012版权年（3000203264） - 10786 SLCC江苏（3000803042） - LID 4548 - SpringerLink江苏eBo联盟2006- 9版权所有（3001144869） - SpringerLink江苏电子书联盟2016-2018版权所有年份（3002351942） - 13433 SpringerLink江苏电子书联盟2013-2015版权所有（3991438083） - SLCC江苏电子期刊联盟2015-2017（3991465546） 42.244.24.216
#
# 沪ICP备15051854号-2
